# %% [markdown]
# ## Eye Disease Detection - Ali Akbar Khan (Improved, Kaggle version)
#
# This is an improved version of the original notebook, adapted to run directly on Kaggle
# (reads from `/kaggle/input`, writes to `/kaggle/working`). Each section has a short note
# explaining *what changed vs the original* and *why it matters*.
#
# Changes made:
# 1. Real train / valid / **test** split (test set is held out before any training)
# 2. Data augmentation added
# 3. `resnet34` + a learning-rate finder instead of a blind `fine_tune`
# 4. Early stopping + best-model checkpointing
# 5. Precision / Recall / F1 / confusion matrix, not just error rate
# 6. Dataset sanity checks (class counts) before training
# 7. Resize a **copy** of the dataset, never the original
# 8. Batch testing on the held-out set instead of one hardcoded image
# 9. Error analysis (top losses, confusion matrix)
# 10. A saved `model_card.json` documenting how the model was built

# %%
# This cell is Kaggle's standard notebook boilerplate - it just lists what's
# available under /kaggle/input so you can see your dataset is attached correctly.
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/1255_right.jpg
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/1482_left.jpg
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/_398_8823411.jpg
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/_309_4110303.jpg
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/_13_697490.jpg
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/_205_310538.jpg
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/Glaucoma_040.png
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/1256_right.jpg
# /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset/glaucoma/_221_3079640.jpg
# ...

# %%
# !pip install -Uqq fastai
from fastai.vision.all import *
import json, shutil
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

# Fix the random seed everywhere (fastai, numpy, torch) so results are reproducible
set_seed(42, reproducible=True)

# %% [markdown]
# ### 1. Find the dataset and check it before doing anything else
#
# On Kaggle, the exact folder name under `/kaggle/input/` depends on how the dataset was
# added (it's not always called `dataset`), so instead of hardcoding a path, this walks
# `/kaggle/input` and finds the folder whose subfolders match your class names. Edit
# `EXPECTED` below to match your actual class folder names.
#
# Then, before touching the images, look at how many you have per class - if one class has
# way fewer images than the others, you need to know *now*, not after training.

# %%
EXPECTED = {'cataract', 'diabetic_retinopathy', 'glaucoma', 'normal'}  # <-- edit to match your dataset's class folder names

def find_dataset_root(base='/kaggle/input'):
    """Walk /kaggle/input and return the first folder whose subfolder names
    (lowercased) match the expected class names, regardless of the exact
    dataset/folder naming Kaggle mounted it with."""
    for root, dirs, files in os.walk(base):
        lower_dirs = {d.lower() for d in dirs}
        if EXPECTED.issubset(lower_dirs) or len(EXPECTED & lower_dirs) >= 3:
            return Path(root)
    raise FileNotFoundError(
        f"Could not auto-locate the class folders under {base}. "
        f"Run: for r,d,f in os.walk('{base}'): print(r) -- and set SRC manually."
    )

SRC = find_dataset_root()
print("Detected dataset root:", SRC)

classes_found = sorted([p.name for p in SRC.iterdir() if p.is_dir()])
print("Classes found:", classes_found)

counts = {c: len(get_image_files(SRC/c)) for c in classes_found}
print(counts)

plt.bar(counts.keys(), counts.values())
plt.title("Images per class (raw)")
plt.ylabel("count")
plt.xticks(rotation=20)
plt.show()
# Out:
# Detected dataset root: /kaggle/input/datasets/gunavenkatdoddi/eye-diseases-classification/dataset
# Classes found: ['cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']
# {'cataract': 1038, 'diabetic_retinopathy': 1098, 'glaucoma': 1007, 'normal': 1074}

# %% [markdown]
# ### 2. Resize a *copy* of the dataset, not the original
#
# The original notebook resized the images in place (`dest=path`), which permanently
# overwrites your source files. On Kaggle `/kaggle/input` is actually read-only so that
# exact mistake isn't possible here - but the right habit is the same anywhere: copy the
# dataset to a working folder first (`/kaggle/working/...`, which is writable) and resize
# the copy, so the original data is never touched.

# %%
WORK = Path('/kaggle/working/dataset')
if WORK.exists():
    shutil.rmtree(WORK)
shutil.copytree(SRC, WORK)

resize_images(WORK, max_size=460, dest=WORK, recurse=True)  # resize the COPY, not the source
print("Resized copies created.")

all_files = get_image_files(WORK)
failed = verify_images(all_files)
print(f"Corrupted/unreadable images found: {len(failed)}")

# Log which classes lost images before deleting them - don't lose that information silently
if len(failed) > 0:
    lost_by_class = pd.Series([f.parent.name for f in failed]).value_counts()
    print("Removed per class:\n", lost_by_class)
    failed.map(Path.unlink)

final_counts = {c: len(get_image_files(WORK/c)) for c in classes_found}
print("Final counts after cleanup:", final_counts)
# Out:
# Resized copies created.
# Corrupted/unreadable images found: 0
# Final counts after cleanup: {'cataract': 1038, 'diabetic_retinopathy': 1098, 'glaucoma': 1007, 'normal': 1074}

# %% [markdown]
# ### 3. A real train / valid / test split
#
# The original notebook only had train/valid, so the "validation" score wasn't a fully
# honest estimate of real-world performance (it gets used, directly or indirectly, to pick
# epochs and settings). Here we carve out a **test set first** and physically move it out
# of the working folder, so it's impossible for it to leak into training or model selection.
#
# We stratify by class so all three splits keep the same class balance.

# %%
fnames = get_image_files(WORK)
labels = [f.parent.name for f in fnames]

train_val_files, test_files = train_test_split(
    fnames, test_size=0.15, stratify=labels, random_state=42
)
train_val_labels = [f.parent.name for f in train_val_files]

train_files, valid_files = train_test_split(
    train_val_files, test_size=0.1765,  # ~15% of the total, since this is 15% of the 85%
    stratify=train_val_labels, random_state=42
)

print(f"Train: {len(train_files)}  Valid: {len(valid_files)}  Test: {len(test_files)}")

# Move the test set physically out of WORK so it can never leak into training/validation
TEST_DIR = Path('/kaggle/working/test_holdout')
if TEST_DIR.exists():
    shutil.rmtree(TEST_DIR)
TEST_DIR.mkdir(exist_ok=True)
for f in test_files:
    dest_dir = TEST_DIR/f.parent.name
    dest_dir.mkdir(exist_ok=True)
    shutil.move(str(f), str(dest_dir/f.name))

print("Held-out test set moved to:", TEST_DIR)
# Out:
# Train: 2951  Valid: 633  Test: 633
# Held-out test set moved to: /kaggle/working/test_holdout

# %% [markdown]
# ### 4. DataLoaders with augmentation
#
# The original notebook only resized images (`Resize(192, method='squish')`) with no
# augmentation, so the model only ever saw each image in exactly one form. Here we add
# `RandomResizedCrop` plus `aug_transforms` (rotation, zoom, lighting, warp) so the model
# learns to be robust to normal real-world variation instead of memorizing exact pixels.

# %%
def get_train_valid_files(path):
    return train_files + valid_files

# Tell fastai exactly which indices are validation, since we already split manually
splitter_idxs = IndexSplitter(list(range(len(train_files), len(train_files) + len(valid_files))))

dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_train_valid_files,
    splitter=splitter_idxs,
    get_y=parent_label,
    item_tfms=[RandomResizedCrop(224, min_scale=0.75)],
    batch_tfms=aug_transforms(size=224, max_rotate=15, max_zoom=1.1, max_lighting=0.2, max_warp=0.1)
).dataloaders(WORK, bs=32)

print("Vocab (classes):", dls.vocab)
dls.show_batch(max_n=12)
# Out:
# Vocab (classes): ['cataract', 'diabetic_retinopathy', 'glaucoma', 'normal']

# %% [markdown]
# ### 5. Pick a real learning rate, and use a stronger backbone
#
# The original notebook used `resnet18` and called `fine_tune(10)` with fastai's default
# learning rate, essentially guessing. Here we switch to `resnet34` (more capacity) and run
# `lr_find()` first, which tests a range of learning rates and shows where loss drops fastest.
# We also track precision, recall and F1 (macro-averaged) in addition to accuracy, since for
# a medical dataset a low error rate can still hide poor performance on one specific disease.

# %%
learn = vision_learner(
    dls, resnet34,
    metrics=[accuracy, error_rate, Precision(average='macro'), Recall(average='macro'), F1Score(average='macro')]
)

lr_min = learn.lr_find()
print(lr_min)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
# 100%|██████████| 83.3M/83.3M [00:00<00:00, 158MB/s]
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
# ...

# %% [markdown]
# ### 6. Train with early stopping and checkpointing
#
# The original notebook ran a fixed 10 epochs with no safety net - if the best epoch was
# epoch 6, epochs 7-10 could have overfit and you'd have no way to recover the better model.
# Here, `EarlyStoppingCallback` stops training if validation loss stops improving, and
# `SaveModelCallback` keeps the best checkpoint automatically.

# %%
cbs = [
    EarlyStoppingCallback(monitor='valid_loss', patience=3),
    SaveModelCallback(monitor='valid_loss', fname='best_model')
]

learn.fine_tune(15, base_lr=lr_min.valley, cbs=cbs)
# Out:
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>accuracy</th><th>error_rate</th><th>precision_score</th><th>recall_score</th><th>f1_score</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>1.165707</td><td>0.546575</td><td>0.808847</td><td>0.191153</td><td>0.810366</td><td>0.807238</td><td>0.806483</td><td>00:14</td></tr></tbody></table></div>
# Better model found at epoch 0 with valid_loss value: 0.5465747117996216.
# ...

# %% [markdown]
# ### 7. Look at what the model got wrong
#
# The original notebook never inspected mistakes. A confusion matrix shows which classes
# get confused with each other, and `plot_top_losses` shows the specific images the model
# was most confidently wrong about - both are useful for catching labeling errors or
# genuinely hard cases.

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix(figsize=(6,6))

interp.plot_top_losses(9, nrows=3)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
preds, targs = learn.get_preds()
pred_classes = preds.argmax(dim=1)
print(classification_report(targs, pred_classes, target_names=dls.vocab))
# Out:
#                       precision    recall  f1-score   support
#
#             cataract       0.99      0.97      0.98       156
# diabetic_retinopathy       1.00      0.99      0.99       165
#             glaucoma       0.94      0.86      0.90       151
#               normal       0.87      0.97      0.92       161
#
#             accuracy                           0.95       633
#            macro avg       0.95      0.95      0.95       633
#         weighted avg       0.95      0.95      0.95       633

# %% [markdown]
# ### 8. Evaluate on the held-out test set
#
# This is the number that actually matters - performance on images the model has never
# influenced training or model-selection decisions with in any way. The original notebook
# never had this at all; it only ever "tested" on validation data and one hand-picked image.

# %%
test_files_final = get_image_files(TEST_DIR)
test_labels_true = [dls.vocab.o2i[f.parent.name] for f in test_files_final]

test_dl = learn.dls.test_dl(test_files_final, with_labels=False)
test_preds, _ = learn.get_preds(dl=test_dl)
test_pred_classes = test_preds.argmax(dim=1)

print("=== HELD-OUT TEST SET RESULTS ===")
print(classification_report(test_labels_true, test_pred_classes, target_names=dls.vocab))

cm = confusion_matrix(test_labels_true, test_pred_classes)
print("Confusion matrix (rows=true, cols=pred):\n", cm)
# Out:
# === HELD-OUT TEST SET RESULTS ===
#                       precision    recall  f1-score   support
#
#             cataract       0.97      0.92      0.94       156
# diabetic_retinopathy       0.97      0.99      0.98       165
#             glaucoma       0.85      0.87      0.86       151
#               normal       0.88      0.89      0.88       161
#
#             accuracy                           0.92       633
#            macro avg       0.92      0.92      0.92       633
#         weighted avg       0.92      0.92      0.92       633
#
# Confusion matrix (rows=true, cols=pred):
#  [[143   0   8   5]
#  [  0 163   2   0]
#  [  4   1 131  15]
#  [  1   4  13 143]]

# %% [markdown]
# ### 9. Spot-check a few predictions visually
#
# Instead of one hardcoded local file path (which only worked on your machine), this pulls
# a random sample straight from the held-out test set, so it always works and always tests
# on genuinely unseen data.

# %%
sample_files = np.random.choice(test_files_final, min(4, len(test_files_final)), replace=False)

fig, axes = plt.subplots(1, len(sample_files), figsize=(4*len(sample_files), 4))
if len(sample_files) == 1:
    axes = [axes]
for ax, f in zip(axes, sample_files):
    pred_class, pred_idx, probs = learn.predict(f)
    true_class = f.parent.name
    img = PILImage.create(f)
    ax.imshow(img)
    ax.set_title(f"true: {true_class}\npred: {pred_class} ({probs[pred_idx]:.2f})", fontsize=9)
    ax.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 10. Export the model and save a model card
#
# Saving a small JSON alongside the model - architecture, dataset sizes, final metrics -
# means you (or anyone else) can understand exactly how this model was trained months later,
# without re-reading the whole notebook.

# %%
learn.export('/kaggle/working/eye_disease_model.pkl')

final_report = classification_report(test_labels_true, test_pred_classes, target_names=dls.vocab, output_dict=True)

model_card = {
    "created": datetime.now().isoformat(),
    "architecture": "resnet34 (fastai vision_learner, fine_tune)",
    "classes": list(dls.vocab),
    "dataset_counts_raw": counts,
    "dataset_counts_after_cleanup": final_counts,
    "split_sizes": {"train": len(train_files), "valid": len(valid_files), "test": len(test_files_final)},
    "test_set_metrics": final_report,
    "notes": "Held-out test set was separated before any training/tuning and never used for model selection."
}

with open('/kaggle/working/model_card.json', 'w') as f:
    json.dump(model_card, f, indent=2)

print("Saved: /kaggle/working/eye_disease_model.pkl + model_card.json")
print(json.dumps(model_card["test_set_metrics"], indent=2))
# Out:
# Saved: /kaggle/working/eye_disease_model.pkl + model_card.json
# {
#   "cataract": {
#     "precision": 0.9662162162162162,
#     "recall": 0.9166666666666666,
#     "f1-score": 0.9407894736842105,
#     "support": 156.0
#   },
#   "diabetic_retinopathy": {
#     "precision": 0.9702380952380952,
#     "recall": 0.9878787878787879,
#     "f1-score": 0.978978978978979,
#     "support": 165.0
#   },
#   "glaucoma": {
#     "precision": 0.8506493506493507,
#     "recall": 0.8675496688741722,
#     "f1-score": 0.8590163934426229,
#     "support": 151.0
#   },
#   "normal": {
#     "precision": 0.8773006134969326,
#     "recall": 0.8881987577639752,
#     "f1-score": 0.8827160493827161,
#     "support": 161.0
#   },
#   "accuracy": 0.9162717219589257,
#   "macro avg": {
#     "precision": 0.9161010689001488,
#     "recall": 0.9150734702959005,
#     "f1-score": 0.9153752238721321,
#     "support": 633.0
#   },
#   "weighted avg": {
#     "precision": 0.917081305158094,
# ...
